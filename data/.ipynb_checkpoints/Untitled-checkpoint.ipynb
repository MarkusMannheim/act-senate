# %%
import pandas as pd, numpy as np

choices = pd.read_csv(
    "2022_choices.csv",
    index_col="code"
)
choices["omitted"] = 0
choices["last"] = 0

votes = pd.read_csv(
    "2022_votes.csv",
    usecols=[1, 2],
    index_col=["voter id"]
)
votes = votes.sample(frac=.25)

def vote_type(prefs):
    prefs = list(prefs)
    types = [choices.at[x, "btl"] for x in prefs]
    if (True in types) & (False in types):
        return np.nan
    elif True in types:
        return "b"
    else:
        return "a"

def above_check(prefs):
    for code in [x for x in choices.index if not choices.at[x, "btl"]]:
        if code not in prefs:
            choices.at[code, "omitted"] = choices.at[code, "omitted"] + 1
    if len(prefs) == 11:
        choices.at[prefs[-1], "last"] = choices.at[prefs[-1], "last"] + 1

def below_check(prefs):
    for code in [x for x in choices.index if choices.at[x, "btl"]]:
        if code not in prefs:
            choices.at[code, "omitted"] = choices.at[code, "omitted"] + 1
    if len(prefs) == 23:
        choices.at[prefs[-1], "last"] = choices.at[prefs[-1], "last"] + 1

for i in votes.index:
    prefs = votes.at[i, "prefs"]
    type_vote = vote_type(prefs)
    votes.at[i, "type"] = type_vote
    if type_vote == "a":
        above_check(prefs)
    if type_vote == "b":
        below_check(prefs)

choices
# Out:
#                                                 PartyNm PartyAb    btl  \
# code
# A                                Australian Labor Party     ALP  False
# B     Sustainable Australia Party - Stop Overdevelop...     SPP  False
# C                                United Australia Party    UAPP  False
# D                                               Liberal      LP  False
# E                                          David Pocock    DAVI  False
# F                                      Kim for Canberra    KCBR  False
# G                               Australian Progressives     AUP  False
# H                                            The Greens     GRN  False
# I                           Legalise Cannabis Australia     HMP  False
# J                                  Animal Justice Party     AJP  False
# K                        Informed Medical Options Party     IMO  False
# L                                Australian Labor Party     ALP   True
# M                                Australian Labor Party     ALP   True
# N     Sustainable Australia Party - Stop Overdevelop...     SPP   True
# O     Sustainable Australia Party - Stop Overdevelop...     SPP   True
# P                                United Australia Party    UAPP   True
# Q                                United Australia Party    UAPP   True
# R                                               Liberal      LP   True
# S                                               Liberal      LP   True
# T                                          David Pocock    DAVI   True
# U                                          David Pocock    DAVI   True
# V                                      Kim for Canberra    KCBR   True
# W                                      Kim for Canberra    KCBR   True
# X                               Australian Progressives     AUP   True
# Y                               Australian Progressives     AUP   True
# Z                                            The Greens     GRN   True
# a                                            The Greens     GRN   True
# b                           Legalise Cannabis Australia     HMP   True
# c                           Legalise Cannabis Australia     HMP   True
# d                                  Animal Justice Party     AJP   True
# e                                  Animal Justice Party     AJP   True
# f                        Informed Medical Options Party     IMO   True
# g                        Informed Medical Options Party     IMO   True
# h                                           Independent     IND   True
#
#               candidateName  omitted  last
# code
# A            GALLAGHER Katy     8202   361
# B                 ANGEL Joy    28140   282
# C          SAVOULIDIS James    33430  1630
# D               SESELJA Zed    18972   990
# E              POCOCK David     7926    72
# F            RUBENSTEIN Kim    14866   119
# G          FAULKNER Therese    31124   370
# H     GORENG GORENG Tjanara    12940   465
# I          KATELARIS Andrew    34652   527
# J            del VALLE Yana    26740   194
# K             SIMMS Michael    36857  1015
# L            GALLAGHER Katy      909    64
# M             NORTHAM Maddy     1215    28
# N                 ANGEL Joy     4257    13
# O               HAYDON John     4814    44
# P          SAVOULIDIS James     6825   243
# Q               PAGE Tracey     6974   444
# R               SESELJA Zed     4810  1230
# S                 LAM Kacey     4739   151
# T              POCOCK David      719    15
# U               DOUBE Clare     1416    22
# V            RUBENSTEIN Kim     1456     4
# W                 HUYNH Kim     2205    22
# X          FAULKNER Therese     4435    11
# Y               LIN Stephen     5045    71
# Z     GORENG GORENG Tjanara     1523    60
# a                CRUZ James     1795   101
# b          KATELARIS Andrew     5007    21
# c          STANVIC Michelle     5397    77
# d            del VALLE Yana     4480    10
# e              FAHIZ Jannah     5132    40
# f             SIMMS Michael     5915   110
# g       LIDDICOAT Mary-Jane     6330   196
# h                  LI Fuxin     6366   437

# %%
choices[choices["btl"]].sort_values("last", ascending=False)
# Out:
#                                                 PartyNm PartyAb   btl  \
# code
# R                                               Liberal      LP  True
# Q                                United Australia Party    UAPP  True
# h                                           Independent     IND  True
# P                                United Australia Party    UAPP  True
# g                        Informed Medical Options Party     IMO  True
# S                                               Liberal      LP  True
# f                        Informed Medical Options Party     IMO  True
# a                                            The Greens     GRN  True
# c                           Legalise Cannabis Australia     HMP  True
# Y                               Australian Progressives     AUP  True
# L                                Australian Labor Party     ALP  True
# Z                                            The Greens     GRN  True
# O     Sustainable Australia Party - Stop Overdevelop...     SPP  True
# e                                  Animal Justice Party     AJP  True
# M                                Australian Labor Party     ALP  True
# U                                          David Pocock    DAVI  True
# W                                      Kim for Canberra    KCBR  True
# b                           Legalise Cannabis Australia     HMP  True
# T                                          David Pocock    DAVI  True
# N     Sustainable Australia Party - Stop Overdevelop...     SPP  True
# X                               Australian Progressives     AUP  True
# d                                  Animal Justice Party     AJP  True
# V                                      Kim for Canberra    KCBR  True
#
#               candidateName  omitted  last
# code
# R               SESELJA Zed     4810  1230
# Q               PAGE Tracey     6974   444
# h                  LI Fuxin     6366   437
# P          SAVOULIDIS James     6825   243
# g       LIDDICOAT Mary-Jane     6330   196
# S                 LAM Kacey     4739   151
# f             SIMMS Michael     5915   110
# a                CRUZ James     1795   101
# c          STANVIC Michelle     5397    77
# Y               LIN Stephen     5045    71
# L            GALLAGHER Katy      909    64
# Z     GORENG GORENG Tjanara     1523    60
# O               HAYDON John     4814    44
# e              FAHIZ Jannah     5132    40
# M             NORTHAM Maddy     1215    28
# U               DOUBE Clare     1416    22
# W                 HUYNH Kim     2205    22
# b          KATELARIS Andrew     5007    21
# T              POCOCK David      719    15
# N                 ANGEL Joy     4257    13
# X          FAULKNER Therese     4435    11
# d            del VALLE Yana     4480    10
# V            RUBENSTEIN Kim     1456     4
